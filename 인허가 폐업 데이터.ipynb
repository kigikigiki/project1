# %%
import pandas as pd
df = pd.read_csv('./영업_폐업상태_데이터.csv')
# Out:
# C:\Users\hyungjun\AppData\Local\Temp\ipykernel_41148\2723031887.py:2: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('./영업_폐업상태_데이터.csv')

# %%
df.head(5)
# Out:
#         인허가일자 상세영업상태명  ...                                         도로명전체주소        사업장명
# 0  2023-11-20      폐업  ...          충청북도 청주시 흥덕구 짐대로72번길 41, 1층 111호 (복대동)        상구맥주
# 1  2023-11-15      폐업  ...  경기도 성남시 수정구 위례서일로 12, 우남 이타워 프라자 1층 109호 (창곡동)      다 아는 맛
# 2  2023-11-15      폐업  ...                   경기도 파주시 문산읍 임진각로 177, 파주임진각광장  북파주어촌계 장석우
# 3  2023-11-15      폐업  ...                                             NaN     두루미평화타운
# 4  2023-11-15      폐업  ...                                             NaN    버들골 교육회관
#
# [5 rows x 6 columns]

# %%
seoul_df = df[df['소재지전체주소'].str.contains('서울특별시')]

# %%
seoul_df
# Out:
#               인허가일자 상세영업상태명  ...                                            도로명전체주소              사업장명
# 12       2023-12-01      폐업  ...    서울특별시 동대문구 왕산로 214, 청량리역,롯데백화점 커넥트플레이스 3층 (전농동)         포동푸딩 주식회사
# 17       2023-09-22      폐업  ...  서울특별시 강남구 봉은사로29길 35, 지하2층 제비201,202,203호,주방2호...          코코아쿡 논현점
# 18       2023-11-27      폐업  ...          서울특별시 서초구 신반포로 176, 신세계백화점 강남점 지하1층 (반포동)               프띠르
# 20       2023-12-01      폐업  ...           서울특별시 강남구 선릉로86길 5-4, 우영빌딩 지상1층 2호 (대치동)       카야루(KAYARU)
# 31       2023-11-27      폐업  ...               서울특별시 강동구 천호대로 1005, 현대백화점 지2층 (천호동)  비비드크로넛 현대백화점 천호점
# ...             ...     ...  ...                                                ...               ...
# 2100057  2020-08-03      영업  ...             서울특별시 은평구 진관2로 29-21, 드림스퀘어 105호 (진관동)        미소야(구파발역점)
# 2100058  2020-08-03      영업  ...                     서울특별시 은평구 북한산로 271-3, 2층 (진관동)         북한산큰숲,제빵소
# ...
